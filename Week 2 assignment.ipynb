# %%
# Open the file in your python notebook, print first 5 rows of the dataset 
import pandas as pd
dataset1=pd.read_csv(r'C:\Users\ruhim\Desktop\cancer dataset.csv')
dataset1.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# #What are the dependent and independent variables in the data?
# diagnosis is a dependent variable and all other variables are independent variables.

# %%
# Find the statistical parameters of the Data that you have
dataset1.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# Find the shape of the Dataset in hand
dataset1.shape
# Out:
# (569, 32)

# %%
# Find the value count of B(Benign) and M(Malignant) cancer cells in the column "diagnosis"
dataset1['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# Find missing values from the Dataset
dataset1.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
# Creating a pairplot and mention the findings
import seaborn as sns
data=dataset1.iloc[:,0:5]
sns.pairplot(data)

# %%
# Create a correlation matrix and mention strongly, weakly and negatively correlated quantities.
data.corr(method="pearson")
# Out:
#                       id  radius_mean  texture_mean  perimeter_mean
# id              1.000000     0.074626      0.099770        0.073159
# radius_mean     0.074626     1.000000      0.323782        0.997855
# texture_mean    0.099770     0.323782      1.000000        0.329533
# perimeter_mean  0.073159     0.997855      0.329533        1.000000

# %% [markdown]
# 1)id and radian_mean are weakly correlated.
# 2)id and texture_mean are weakly correlated.
# 3)id and perimeter_mean are weakly correlated.
# 4)radius_mean and texture_mean are weakly correlated.
# 5)radius_mean and perimeter_mean are strongly correlated.
# 6)texture_mean and radius_mean are weakly correlated.
# 7)texture_mean and perimeter_mean are weakly correlated.

# %%
# Create a heatmap of the correlated features (helps in visualization)
sns.heatmap(data.corr(), annot=True,fmt="0.0%")
